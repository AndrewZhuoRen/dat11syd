# %% [markdown]
# # Introduction to Data Science with Python
# ## General Assembly
# ## Natural Language Processing (NLP)
#
# Make sure you have installed spacy ( `!pip install spacy` ) and successfully run `!python -m spacy download en`

# %%
# !pip install spacy
# !python –m spacy download en
# Out:
# Collecting spacy
#   Using cached spacy-2.0.11.tar.gz
# Requirement already satisfied: numpy>=1.7 in c:\users\andrew\anaconda3\lib\site-packages (from spacy)
# Collecting murmurhash<0.29,>=0.28 (from spacy)
#   Using cached murmurhash-0.28.0.tar.gz
# Collecting cymem<1.32,>=1.30 (from spacy)
#   Using cached cymem-1.31.2.tar.gz
# Collecting preshed<2.0.0,>=1.0.0 (from spacy)
#   Using cached preshed-1.0.0.tar.gz
# Collecting thinc<6.11.0,>=6.10.1 (from spacy)
#   Using cached thinc-6.10.2.tar.gz
# Collecting plac<1.0.0,>=0.9.6 (from spacy)
#   Using cached plac-0.9.6-py2.py3-none-any.whl
# Collecting pathlib (from spacy)
# Collecting ujson>=1.35 (from spacy)
#   Using cached ujson-1.35.tar.gz
# Collecting dill<0.3,>=0.2 (from spacy)
# Collecting regex==2017.4.5 (from spacy)
#   Using cached regex-2017.04.05-cp36-none-win_amd64.whl
# Requirement already satisfied: wrapt in c:\users\andrew\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy)
# Collecting tqdm<5.0.0,>=4.10.0 (from thinc<6.11.0,>=6.10.1->spacy)
#   Using cached tqdm-4.21.0-py2.py3-none-any.whl
# Collecting cytoolz<0.9,>=0.8 (from thinc<6.11.0,>=6.10.1->spacy)
#   Using cached cytoolz-0.8.2.tar.gz
# Requirement already satisfied: six<2.0.0,>=1.10.0 in c:\users\andrew\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy)
# Collecting termcolor (from thinc<6.11.0,>=6.10.1->spacy)
# Requirement already satisfied: msgpack-python in c:\users\andrew\anaconda3\lib\site-packages (from thinc<6.11.0,>=6.10.1->spacy)
# Collecting msgpack-numpy==0.4.1 (from thinc<6.11.0,>=6.10.1->spacy)
#   Using cached msgpack_numpy-0.4.1-py2.py3-none-any.whl
# Collecting pyreadline>=1.7.1 (from dill<0.3,>=0.2->spacy)
# Requirement already satisfied: toolz>=0.8.0 in c:\users\andrew\anaconda3\lib\site-packages (from cytoolz<0.9,>=0.8->thinc<6.11.0,>=6.10.1->spacy)
# Building wheels for collected packages: spacy, murmurhash, cymem, preshed, thinc, ujson, cytoolz
#   Running setup.py bdist_wheel for spacy: started
#   Running setup.py bdist_wheel for spacy: finished with status 'error'
#   Complete output from command C:\Users\Andrew\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\Andrew\\AppData\\Local\\Temp\\pip-build-bk63fsa9\\spacy\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\Andrew\AppData\Local\Temp\tmpt7umzc4mpip-wheel- --python-tag cp36:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.6
#   creating build\lib.win-amd64-3.6\spacy
#   copying spacy\about.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\compat.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\errors.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\glossary.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\language.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\lemmatizer.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\scorer.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\util.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\_ml.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\__init__.py -> build\lib.win-amd64-3.6\spacy
#   copying spacy\__main__.py -> build\lib.win-amd64-3.6\spacy
#   creating build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\convert.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\download.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\evaluate.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\info.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\init_model.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\link.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\package.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\profile.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\train.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\validate.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\vocab.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\_messages.py -> build\lib.win-amd64-3.6\spacy\cli
#   copying spacy\cli\__init__.py -> build\lib.win-amd64-3.6\spacy\cli
#   creating build\lib.win-amd64-3.6\spacy\data
#   copying spacy\data\__init__.py -> build\lib.win-amd64-3.6\spacy\data
#   creating build\lib.win-amd64-3.6\spacy\displacy
#   copying spacy\displacy\render.py -> build\lib.win-amd64-3.6\spacy\displacy
#   copying spacy\displacy\templates.py -> build\lib.win-amd64-3.6\spacy\displacy
#   copying spacy\displacy\__init__.py -> build\lib.win-amd64-3.6\spacy\displacy
#   creating build\lib.win-amd64-3.6\spacy\lang
#   copying spacy\lang\char_classes.py -> build\lib.win-amd64-3.6\spacy\lang
#   copying spacy\lang\entity_rules.py -> build\lib.win-amd64-3.6\spacy\lang
#   copying spacy\lang\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang
#   copying spacy\lang\norm_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang
#   copying spacy\lang\punctuation.py -> build\lib.win-amd64-3.6\spacy\lang
#   copying spacy\lang\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang
#   copying spacy\lang\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang
#   copying spacy\lang\__init__.py -> build\lib.win-amd64-3.6\spacy\lang
#   creating build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\__init__.py -> build\lib.win-amd64-3.6\spacy\syntax
#   creating build\lib.win-amd64-3.6\spacy\tests
#   copying spacy\tests\conftest.py -> build\lib.win-amd64-3.6\spacy\tests
#   copying spacy\tests\test_matcher.py -> build\lib.win-amd64-3.6\spacy\tests
#   copying spacy\tests\test_misc.py -> build\lib.win-amd64-3.6\spacy\tests
#   copying spacy\tests\test_pickles.py -> build\lib.win-amd64-3.6\spacy\tests
#   copying spacy\tests\test_underscore.py -> build\lib.win-amd64-3.6\spacy\tests
#   copying spacy\tests\util.py -> build\lib.win-amd64-3.6\spacy\tests
#   copying spacy\tests\__init__.py -> build\lib.win-amd64-3.6\spacy\tests
#   creating build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\printers.py -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\underscore.py -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\__init__.py -> build\lib.win-amd64-3.6\spacy\tokens
#   creating build\lib.win-amd64-3.6\spacy\cli\converters
#   copying spacy\cli\converters\conllu2json.py -> build\lib.win-amd64-3.6\spacy\cli\converters
#   copying spacy\cli\converters\conll_ner2json.py -> build\lib.win-amd64-3.6\spacy\cli\converters
#   copying spacy\cli\converters\iob2json.py -> build\lib.win-amd64-3.6\spacy\cli\converters
#   copying spacy\cli\converters\__init__.py -> build\lib.win-amd64-3.6\spacy\cli\converters
#   creating build\lib.win-amd64-3.6\spacy\lang\bn
#   copying spacy\lang\bn\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\bn
#   copying spacy\lang\bn\morph_rules.py -> build\lib.win-amd64-3.6\spacy\lang\bn
#   copying spacy\lang\bn\punctuation.py -> build\lib.win-amd64-3.6\spacy\lang\bn
#   copying spacy\lang\bn\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\bn
#   copying spacy\lang\bn\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\bn
#   copying spacy\lang\bn\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\bn
#   copying spacy\lang\bn\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\bn
#   creating build\lib.win-amd64-3.6\spacy\lang\da
#   copying spacy\lang\da\examples.py -> build\lib.win-amd64-3.6\spacy\lang\da
#   copying spacy\lang\da\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\da
#   copying spacy\lang\da\morph_rules.py -> build\lib.win-amd64-3.6\spacy\lang\da
#   copying spacy\lang\da\norm_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\da
#   copying spacy\lang\da\punctuation.py -> build\lib.win-amd64-3.6\spacy\lang\da
#   copying spacy\lang\da\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\da
#   copying spacy\lang\da\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\da
#   copying spacy\lang\da\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\da
#   creating build\lib.win-amd64-3.6\spacy\lang\de
#   copying spacy\lang\de\examples.py -> build\lib.win-amd64-3.6\spacy\lang\de
#   copying spacy\lang\de\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\de
#   copying spacy\lang\de\norm_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\de
#   copying spacy\lang\de\punctuation.py -> build\lib.win-amd64-3.6\spacy\lang\de
#   copying spacy\lang\de\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\de
#   copying spacy\lang\de\syntax_iterators.py -> build\lib.win-amd64-3.6\spacy\lang\de
#   copying spacy\lang\de\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\de
#   copying spacy\lang\de\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\de
#   copying spacy\lang\de\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\de
#   creating build\lib.win-amd64-3.6\spacy\lang\en
#   copying spacy\lang\en\examples.py -> build\lib.win-amd64-3.6\spacy\lang\en
#   copying spacy\lang\en\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\en
#   copying spacy\lang\en\morph_rules.py -> build\lib.win-amd64-3.6\spacy\lang\en
#   copying spacy\lang\en\norm_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\en
#   copying spacy\lang\en\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\en
#   copying spacy\lang\en\syntax_iterators.py -> build\lib.win-amd64-3.6\spacy\lang\en
#   copying spacy\lang\en\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\en
#   copying spacy\lang\en\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\en
#   copying spacy\lang\en\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\en
#   creating build\lib.win-amd64-3.6\spacy\lang\es
#   copying spacy\lang\es\examples.py -> build\lib.win-amd64-3.6\spacy\lang\es
#   copying spacy\lang\es\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\es
#   copying spacy\lang\es\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\es
#   copying spacy\lang\es\syntax_iterators.py -> build\lib.win-amd64-3.6\spacy\lang\es
#   copying spacy\lang\es\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\es
#   copying spacy\lang\es\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\es
#   copying spacy\lang\es\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\es
#   creating build\lib.win-amd64-3.6\spacy\lang\fa
#   copying spacy\lang\fa\examples.py -> build\lib.win-amd64-3.6\spacy\lang\fa
#   copying spacy\lang\fa\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\fa
#   copying spacy\lang\fa\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\fa
#   creating build\lib.win-amd64-3.6\spacy\lang\fi
#   copying spacy\lang\fi\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\fi
#   copying spacy\lang\fi\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\fi
#   copying spacy\lang\fi\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\fi
#   creating build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\examples.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\punctuation.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\syntax_iterators.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\_tokenizer_exceptions_list.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   copying spacy\lang\fr\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\fr
#   creating build\lib.win-amd64-3.6\spacy\lang\ga
#   copying spacy\lang\ga\irish_morphology_helpers.py -> build\lib.win-amd64-3.6\spacy\lang\ga
#   copying spacy\lang\ga\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\ga
#   copying spacy\lang\ga\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\ga
#   copying spacy\lang\ga\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\ga
#   copying spacy\lang\ga\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\ga
#   creating build\lib.win-amd64-3.6\spacy\lang\he
#   copying spacy\lang\he\examples.py -> build\lib.win-amd64-3.6\spacy\lang\he
#   copying spacy\lang\he\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\he
#   copying spacy\lang\he\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\he
#   creating build\lib.win-amd64-3.6\spacy\lang\hi
#   copying spacy\lang\hi\examples.py -> build\lib.win-amd64-3.6\spacy\lang\hi
#   copying spacy\lang\hi\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\hi
#   copying spacy\lang\hi\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\hi
#   copying spacy\lang\hi\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\hi
#   creating build\lib.win-amd64-3.6\spacy\lang\hr
#   copying spacy\lang\hr\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\hr
#   copying spacy\lang\hr\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\hr
#   creating build\lib.win-amd64-3.6\spacy\lang\hu
#   copying spacy\lang\hu\examples.py -> build\lib.win-amd64-3.6\spacy\lang\hu
#   copying spacy\lang\hu\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\hu
#   copying spacy\lang\hu\punctuation.py -> build\lib.win-amd64-3.6\spacy\lang\hu
#   copying spacy\lang\hu\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\hu
#   copying spacy\lang\hu\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\hu
#   copying spacy\lang\hu\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\hu
#   creating build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\examples.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\norm_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\punctuation.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\syntax_iterators.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\_tokenizer_exceptions_list.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   copying spacy\lang\id\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\id
#   creating build\lib.win-amd64-3.6\spacy\lang\it
#   copying spacy\lang\it\examples.py -> build\lib.win-amd64-3.6\spacy\lang\it
#   copying spacy\lang\it\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\it
#   copying spacy\lang\it\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\it
#   copying spacy\lang\it\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\it
#   copying spacy\lang\it\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\it
#   creating build\lib.win-amd64-3.6\spacy\lang\ja
#   copying spacy\lang\ja\examples.py -> build\lib.win-amd64-3.6\spacy\lang\ja
#   copying spacy\lang\ja\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\ja
#   creating build\lib.win-amd64-3.6\spacy\lang\nb
#   copying spacy\lang\nb\examples.py -> build\lib.win-amd64-3.6\spacy\lang\nb
#   copying spacy\lang\nb\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\nb
#   copying spacy\lang\nb\morph_rules.py -> build\lib.win-amd64-3.6\spacy\lang\nb
#   copying spacy\lang\nb\punctuation.py -> build\lib.win-amd64-3.6\spacy\lang\nb
#   copying spacy\lang\nb\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\nb
#   copying spacy\lang\nb\syntax_iterators.py -> build\lib.win-amd64-3.6\spacy\lang\nb
#   copying spacy\lang\nb\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\nb
#   copying spacy\lang\nb\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\nb
#   copying spacy\lang\nb\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\nb
#   creating build\lib.win-amd64-3.6\spacy\lang\nl
#   copying spacy\lang\nl\examples.py -> build\lib.win-amd64-3.6\spacy\lang\nl
#   copying spacy\lang\nl\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\nl
#   copying spacy\lang\nl\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\nl
#   copying spacy\lang\nl\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\nl
#   copying spacy\lang\nl\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\nl
#   creating build\lib.win-amd64-3.6\spacy\lang\pl
#   copying spacy\lang\pl\examples.py -> build\lib.win-amd64-3.6\spacy\lang\pl
#   copying spacy\lang\pl\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\pl
#   copying spacy\lang\pl\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\pl
#   copying spacy\lang\pl\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\pl
#   creating build\lib.win-amd64-3.6\spacy\lang\pt
#   copying spacy\lang\pt\examples.py -> build\lib.win-amd64-3.6\spacy\lang\pt
#   copying spacy\lang\pt\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\pt
#   copying spacy\lang\pt\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\pt
#   copying spacy\lang\pt\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\pt
#   copying spacy\lang\pt\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\pt
#   copying spacy\lang\pt\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\pt
#   copying spacy\lang\pt\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\pt
#   creating build\lib.win-amd64-3.6\spacy\lang\ro
#   copying spacy\lang\ro\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\ro
#   copying spacy\lang\ro\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\ro
#   copying spacy\lang\ro\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\ro
#   creating build\lib.win-amd64-3.6\spacy\lang\ru
#   copying spacy\lang\ru\examples.py -> build\lib.win-amd64-3.6\spacy\lang\ru
#   copying spacy\lang\ru\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\ru
#   copying spacy\lang\ru\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\ru
#   copying spacy\lang\ru\norm_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\ru
#   copying spacy\lang\ru\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\ru
#   copying spacy\lang\ru\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\ru
#   copying spacy\lang\ru\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\ru
#   copying spacy\lang\ru\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\ru
#   creating build\lib.win-amd64-3.6\spacy\lang\sv
#   copying spacy\lang\sv\examples.py -> build\lib.win-amd64-3.6\spacy\lang\sv
#   copying spacy\lang\sv\morph_rules.py -> build\lib.win-amd64-3.6\spacy\lang\sv
#   copying spacy\lang\sv\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\sv
#   copying spacy\lang\sv\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\sv
#   copying spacy\lang\sv\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\sv
#   creating build\lib.win-amd64-3.6\spacy\lang\th
#   copying spacy\lang\th\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\th
#   copying spacy\lang\th\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\th
#   copying spacy\lang\th\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\th
#   copying spacy\lang\th\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\th
#   creating build\lib.win-amd64-3.6\spacy\lang\tr
#   copying spacy\lang\tr\examples.py -> build\lib.win-amd64-3.6\spacy\lang\tr
#   copying spacy\lang\tr\lemmatizer.py -> build\lib.win-amd64-3.6\spacy\lang\tr
#   copying spacy\lang\tr\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\tr
#   copying spacy\lang\tr\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\tr
#   copying spacy\lang\tr\tokenizer_exceptions.py -> build\lib.win-amd64-3.6\spacy\lang\tr
#   copying spacy\lang\tr\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\tr
#   creating build\lib.win-amd64-3.6\spacy\lang\vi
#   copying spacy\lang\vi\lex_attrs.py -> build\lib.win-amd64-3.6\spacy\lang\vi
#   copying spacy\lang\vi\stop_words.py -> build\lib.win-amd64-3.6\spacy\lang\vi
#   copying spacy\lang\vi\tag_map.py -> build\lib.win-amd64-3.6\spacy\lang\vi
#   copying spacy\lang\vi\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\vi
#   creating build\lib.win-amd64-3.6\spacy\lang\xx
#   copying spacy\lang\xx\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\xx
#   creating build\lib.win-amd64-3.6\spacy\lang\zh
#   copying spacy\lang\zh\examples.py -> build\lib.win-amd64-3.6\spacy\lang\zh
#   copying spacy\lang\zh\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\zh
#   creating build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\lookup.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adjectives.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adjectives_irreg.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adverbs.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_adverbs_irreg.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_lemma_rules.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_nouns.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_nouns_irreg.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_verbs.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\_verbs_irreg.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   copying spacy\lang\en\lemmatizer\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\en\lemmatizer
#   creating build\lib.win-amd64-3.6\spacy\lang\sv\lemmatizer
#   copying spacy\lang\sv\lemmatizer\lookup.py -> build\lib.win-amd64-3.6\spacy\lang\sv\lemmatizer
#   copying spacy\lang\sv\lemmatizer\__init__.py -> build\lib.win-amd64-3.6\spacy\lang\sv\lemmatizer
#   creating build\lib.win-amd64-3.6\spacy\tests\doc
#   copying spacy\tests\doc\test_add_entities.py -> build\lib.win-amd64-3.6\spacy\tests\doc
#   copying spacy\tests\doc\test_array.py -> build\lib.win-amd64-3.6\spacy\tests\doc
#   copying spacy\tests\doc\test_creation.py -> build\lib.win-amd64-3.6\spacy\tests\doc
#   copying spacy\tests\doc\test_doc_api.py -> build\lib.win-amd64-3.6\spacy\tests\doc
#   copying spacy\tests\doc\test_pickle_doc.py -> build\lib.win-amd64-3.6\spacy\tests\doc
#   copying spacy\tests\doc\test_span.py -> build\lib.win-amd64-3.6\spacy\tests\doc
#   copying spacy\tests\doc\test_span_merge.py -> build\lib.win-amd64-3.6\spacy\tests\doc
#   copying spacy\tests\doc\test_token_api.py -> build\lib.win-amd64-3.6\spacy\tests\doc
#   copying spacy\tests\doc\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\doc
#   creating build\lib.win-amd64-3.6\spacy\tests\gold
#   copying spacy\tests\gold\test_biluo.py -> build\lib.win-amd64-3.6\spacy\tests\gold
#   copying spacy\tests\gold\test_lev_align.py -> build\lib.win-amd64-3.6\spacy\tests\gold
#   copying spacy\tests\gold\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\gold
#   creating build\lib.win-amd64-3.6\spacy\tests\lang
#   copying spacy\tests\lang\test_attrs.py -> build\lib.win-amd64-3.6\spacy\tests\lang
#   copying spacy\tests\lang\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang
#   creating build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_add_label.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_beam_parse.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_ner.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_neural_parser.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_nn_beam.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_nonproj.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_parse.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_parse_navigate.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_preset_sbd.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_space_attachment.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\test_to_from_bytes_disk.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   copying spacy\tests\parser\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\parser
#   creating build\lib.win-amd64-3.6\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_factories.py -> build\lib.win-amd64-3.6\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_pipe_methods.py -> build\lib.win-amd64-3.6\spacy\tests\pipeline
#   copying spacy\tests\pipeline\test_textcat.py -> build\lib.win-amd64-3.6\spacy\tests\pipeline
#   copying spacy\tests\pipeline\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\pipeline
#   creating build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue118.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1207.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1242.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1250.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1253.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1257.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1305.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1375.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1380.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1387.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1434.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1450.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1488.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1494.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1506.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1518.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1537.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1539.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1547.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1612.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1622.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1654.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1660.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1698.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1727.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1757.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1758.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1769.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1799.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1807.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1834.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1868.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1883.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1915.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1919.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1945.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1959.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue1967.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue242.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue309.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue351.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue360.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue361.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue401.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue429.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue514.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue54.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue587.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue588.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue589.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue590.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue595.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue599.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue600.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue615.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue686.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue693.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue704.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue717.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue719.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue736.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue740.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue743.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue744.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue758.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue759.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue768.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue775.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue781.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue792.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue801.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue805.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue834.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue850.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue852.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue859.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue886.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue891.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue903.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue910.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue912.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue957.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue995.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\test_issue999.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   copying spacy\tests\regression\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\regression
#   creating build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialization.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_doc.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_empty_model.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_extension_attrs.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_language.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_parser_ner.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_stringstore.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_tagger.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_tensorizer.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\test_serialize_vocab.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   copying spacy\tests\serialize\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\serialize
#   creating build\lib.win-amd64-3.6\spacy\tests\stringstore
#   copying spacy\tests\stringstore\test_freeze_string_store.py -> build\lib.win-amd64-3.6\spacy\tests\stringstore
#   copying spacy\tests\stringstore\test_stringstore.py -> build\lib.win-amd64-3.6\spacy\tests\stringstore
#   copying spacy\tests\stringstore\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\stringstore
#   creating build\lib.win-amd64-3.6\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_exceptions.py -> build\lib.win-amd64-3.6\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_naughty_strings.py -> build\lib.win-amd64-3.6\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_urls.py -> build\lib.win-amd64-3.6\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\test_whitespace.py -> build\lib.win-amd64-3.6\spacy\tests\tokenizer
#   copying spacy\tests\tokenizer\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\tokenizer
#   creating build\lib.win-amd64-3.6\spacy\tests\vectors
#   copying spacy\tests\vectors\test_similarity.py -> build\lib.win-amd64-3.6\spacy\tests\vectors
#   copying spacy\tests\vectors\test_vectors.py -> build\lib.win-amd64-3.6\spacy\tests\vectors
#   copying spacy\tests\vectors\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\vectors
#   creating build\lib.win-amd64-3.6\spacy\tests\vocab
#   copying spacy\tests\vocab\test_add_vectors.py -> build\lib.win-amd64-3.6\spacy\tests\vocab
#   copying spacy\tests\vocab\test_lexeme.py -> build\lib.win-amd64-3.6\spacy\tests\vocab
#   copying spacy\tests\vocab\test_vocab_api.py -> build\lib.win-amd64-3.6\spacy\tests\vocab
#   copying spacy\tests\vocab\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\vocab
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\bn
#   copying spacy\tests\lang\bn\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\bn
#   copying spacy\tests\lang\bn\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\bn
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\da
#   copying spacy\tests\lang\da\test_exceptions.py -> build\lib.win-amd64-3.6\spacy\tests\lang\da
#   copying spacy\tests\lang\da\test_prefix_suffix_infix.py -> build\lib.win-amd64-3.6\spacy\tests\lang\da
#   copying spacy\tests\lang\da\test_text.py -> build\lib.win-amd64-3.6\spacy\tests\lang\da
#   copying spacy\tests\lang\da\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\da
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_exceptions.py -> build\lib.win-amd64-3.6\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_lemma.py -> build\lib.win-amd64-3.6\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_models.py -> build\lib.win-amd64-3.6\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_parser.py -> build\lib.win-amd64-3.6\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_prefix_suffix_infix.py -> build\lib.win-amd64-3.6\spacy\tests\lang\de
#   copying spacy\tests\lang\de\test_text.py -> build\lib.win-amd64-3.6\spacy\tests\lang\de
#   copying spacy\tests\lang\de\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\de
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_customized_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_exceptions.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_indices.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_lemmatizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_models.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_ner.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_noun_chunks.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_parser.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_prefix_suffix_infix.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_punct.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_sbd.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_tagger.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\test_text.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   copying spacy\tests\lang\en\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\en
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\es
#   copying spacy\tests\lang\es\test_exception.py -> build\lib.win-amd64-3.6\spacy\tests\lang\es
#   copying spacy\tests\lang\es\test_text.py -> build\lib.win-amd64-3.6\spacy\tests\lang\es
#   copying spacy\tests\lang\es\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\es
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\fi
#   copying spacy\tests\lang\fi\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\fi
#   copying spacy\tests\lang\fi\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\fi
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\fr
#   copying spacy\tests\lang\fr\test_exceptions.py -> build\lib.win-amd64-3.6\spacy\tests\lang\fr
#   copying spacy\tests\lang\fr\test_lemmatization.py -> build\lib.win-amd64-3.6\spacy\tests\lang\fr
#   copying spacy\tests\lang\fr\test_text.py -> build\lib.win-amd64-3.6\spacy\tests\lang\fr
#   copying spacy\tests\lang\fr\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\fr
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\ga
#   copying spacy\tests\lang\ga\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\ga
#   copying spacy\tests\lang\ga\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\ga
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\he
#   copying spacy\tests\lang\he\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\he
#   copying spacy\tests\lang\he\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\he
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\hu
#   copying spacy\tests\lang\hu\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\hu
#   copying spacy\tests\lang\hu\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\hu
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\id
#   copying spacy\tests\lang\id\test_prefix_suffix_infix.py -> build\lib.win-amd64-3.6\spacy\tests\lang\id
#   copying spacy\tests\lang\id\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\id
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\ja
#   copying spacy\tests\lang\ja\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\ja
#   copying spacy\tests\lang\ja\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\ja
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\nb
#   copying spacy\tests\lang\nb\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\nb
#   copying spacy\tests\lang\nb\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\nb
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\ru
#   copying spacy\tests\lang\ru\test_lemmatizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\ru
#   copying spacy\tests\lang\ru\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\ru
#   copying spacy\tests\lang\ru\test_tokenizer_exc.py -> build\lib.win-amd64-3.6\spacy\tests\lang\ru
#   copying spacy\tests\lang\ru\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\ru
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\sv
#   copying spacy\tests\lang\sv\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\sv
#   copying spacy\tests\lang\sv\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\sv
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\th
#   copying spacy\tests\lang\th\test_tokenizer.py -> build\lib.win-amd64-3.6\spacy\tests\lang\th
#   copying spacy\tests\lang\th\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\th
#   creating build\lib.win-amd64-3.6\spacy\tests\lang\tr
#   copying spacy\tests\lang\tr\test_lemmatization.py -> build\lib.win-amd64-3.6\spacy\tests\lang\tr
#   copying spacy\tests\lang\tr\__init__.py -> build\lib.win-amd64-3.6\spacy\tests\lang\tr
#   copying spacy\attrs.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\gold.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\lexeme.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\matcher.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\morphology.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\parts_of_speech.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\pipeline.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\strings.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\symbols.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\tokenizer.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\typedefs.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\vectors.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\vocab.pyx -> build\lib.win-amd64-3.6\spacy
#   copying spacy\attrs.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\gold.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\lexeme.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\morphology.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\parts_of_speech.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\pipeline.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\strings.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\structs.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\symbols.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\tokenizer.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\typedefs.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\vocab.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\__init__.pxd -> build\lib.win-amd64-3.6\spacy
#   copying spacy\syntax\arc_eager.pyx -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\ner.pyx -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\nn_parser.pyx -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\nonproj.pyx -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\stateclass.pyx -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\transition_system.pyx -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\_beam_utils.pyx -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\_state.pyx -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\arc_eager.pxd -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\ner.pxd -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\nn_parser.pxd -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\nonproj.pxd -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\stateclass.pxd -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\transition_system.pxd -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\_state.pxd -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\syntax\__init__.pxd -> build\lib.win-amd64-3.6\spacy\syntax
#   copying spacy\tokens\doc.pyx -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\span.pyx -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\token.pyx -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\_retokenize.pyx -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\doc.pxd -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\span.pxd -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\token.pxd -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tokens\__init__.pxd -> build\lib.win-amd64-3.6\spacy\tokens
#   copying spacy\tests\tokenizer\sun.txt -> build\lib.win-amd64-3.6\spacy\tests\tokenizer
#   running build_ext
#   building 'spacy.parts_of_speech' extension
#   error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": http://landinghub.visualstudio.com/visual-cpp-build-tools
#
#   ----------------------------------------
#   Running setup.py clean for spacy
#   Running setup.py bdist_wheel for murmurhash: started
#   Running setup.py bdist_wheel for murmurhash: finished with status 'error'
#   Complete output from command C:\Users\Andrew\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\Andrew\\AppData\\Local\\Temp\\pip-build-bk63fsa9\\murmurhash\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\Andrew\AppData\Local\Temp\tmpo1ejaw3tpip-wheel- --python-tag cp36:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.6
#   creating build\lib.win-amd64-3.6\murmurhash
#   copying murmurhash\about.py -> build\lib.win-amd64-3.6\murmurhash
#   copying murmurhash\__init__.py -> build\lib.win-amd64-3.6\murmurhash
#   creating build\lib.win-amd64-3.6\murmurhash\tests
#   copying murmurhash\tests\test_import.py -> build\lib.win-amd64-3.6\murmurhash\tests
#   copying murmurhash\tests\__init__.py -> build\lib.win-amd64-3.6\murmurhash\tests
#   copying murmurhash\mrmr.pyx -> build\lib.win-amd64-3.6\murmurhash
#   copying murmurhash\mrmr.pxd -> build\lib.win-amd64-3.6\murmurhash
#   copying murmurhash\__init__.pxd -> build\lib.win-amd64-3.6\murmurhash
#   creating build\lib.win-amd64-3.6\murmurhash\include
#   creating build\lib.win-amd64-3.6\murmurhash\include\murmurhash
#   copying murmurhash\include\murmurhash\MurmurHash2.h -> build\lib.win-amd64-3.6\murmurhash\include\murmurhash
#   copying murmurhash\include\murmurhash\MurmurHash3.h -> build\lib.win-amd64-3.6\murmurhash\include\murmurhash
#   running build_ext
#   building 'murmurhash.mrmr' extension
# ...
#   copying thinc\tests\unit\test_pooling.py -> build\lib.win-amd64-3.6\thinc\tests\unit
#   copying thinc\tests\unit\test_rnn.py -> build\lib.win-amd64-3.6\thinc\tests\unit
#   copying thinc\tests\unit\__init__.py -> build\lib.win-amd64-3.6\thinc\tests\unit
#   creating build\lib.win-amd64-3.6\thinc\tests\integration
#   copying thinc\tests\integration\test_affine_learns.py -> build\lib.win-amd64-3.6\thinc\tests\integration
#   copying thinc\tests\integration\test_basic_tagger.py -> build\lib.win-amd64-3.6\thinc\tests\integration
#   copying thinc\tests\integration\test_batch_norm.py -> build\lib.win-amd64-3.6\thinc\tests\integration
#   copying thinc\tests\integration\test_feed_forward.py -> build\lib.win-amd64-3.6\thinc\tests\integration
#   copying thinc\tests\integration\test_mnist.py -> build\lib.win-amd64-3.6\thinc\tests\integration
#   copying thinc\tests\integration\test_roundtrip_bytes.py -> build\lib.win-amd64-3.6\thinc\tests\integration
#   copying thinc\tests\integration\test_shape_check.py -> build\lib.win-amd64-3.6\thinc\tests\integration
#   copying thinc\tests\integration\__init__.py -> build\lib.win-amd64-3.6\thinc\tests\integration
#   creating build\lib.win-amd64-3.6\thinc\tests\linear
#   copying thinc\tests\linear\test_avgtron.py -> build\lib.win-amd64-3.6\thinc\tests\linear
#   copying thinc\tests\linear\test_linear.py -> build\lib.win-amd64-3.6\thinc\tests\linear
#   copying thinc\tests\linear\test_sparse_array.py -> build\lib.win-amd64-3.6\thinc\tests\linear
#   copying thinc\tests\linear\__init__.py -> build\lib.win-amd64-3.6\thinc\tests\linear
#   creating build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\__init__.py -> build\lib.win-amd64-3.6\thinc\linear
#   creating build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\mem.py -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\pooling.py -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\train.py -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\util.py -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\vec2vec.py -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\vecs2vec.py -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\vecs2vecs.py -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\_lsuv.py -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\__init__.py -> build\lib.win-amd64-3.6\thinc\neural
#   creating build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\datasets.py -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\hpbff.py -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\load_nlp.py -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\wrappers.py -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\__init__.py -> build\lib.win-amd64-3.6\thinc\extra
#   creating build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\affine.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\attention.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\batchnorm.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\convolution.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\difference.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\elu.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\embed.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\feed_forward.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\hash_embed.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\layernorm.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\lstm.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\maxout.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\model.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\relu.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\resnet.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\rnn.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\selu.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\softmax.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\static_vectors.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   copying thinc\neural\_classes\__init__.py -> build\lib.win-amd64-3.6\thinc\neural\_classes
#   creating build\lib.win-amd64-3.6\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_datasets.py -> build\lib.win-amd64-3.6\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_data_utils.py -> build\lib.win-amd64-3.6\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\keras_generic_utils.py -> build\lib.win-amd64-3.6\thinc\extra\_vendorized
#   copying thinc\extra\_vendorized\__init__.py -> build\lib.win-amd64-3.6\thinc\extra\_vendorized
#   copying thinc\linalg.pyx -> build\lib.win-amd64-3.6\thinc
#   copying thinc\structs.pyx -> build\lib.win-amd64-3.6\thinc
#   copying thinc\typedefs.pyx -> build\lib.win-amd64-3.6\thinc
#   copying thinc\linalg.pxd -> build\lib.win-amd64-3.6\thinc
#   copying thinc\structs.pxd -> build\lib.win-amd64-3.6\thinc
#   copying thinc\typedefs.pxd -> build\lib.win-amd64-3.6\thinc
#   copying thinc\__init__.pxd -> build\lib.win-amd64-3.6\thinc
#   copying thinc\compile_time_constants.pxi -> build\lib.win-amd64-3.6\thinc
#   copying thinc\linalg.cpp -> build\lib.win-amd64-3.6\thinc
#   copying thinc\structs.cpp -> build\lib.win-amd64-3.6\thinc
#   copying thinc\typedefs.cpp -> build\lib.win-amd64-3.6\thinc
#   copying thinc\linear\avgtron.pyx -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\features.pyx -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\linear.pyx -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\serialize.pyx -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\sparse.pyx -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\avgtron.pxd -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\features.pxd -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\serialize.pxd -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\sparse.pxd -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\__init__.pxd -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\avgtron.cpp -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\features.cpp -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\linear.cpp -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\serialize.cpp -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\linear\sparse.cpp -> build\lib.win-amd64-3.6\thinc\linear
#   copying thinc\neural\gpu_ops.pyx -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\ops.pyx -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\optimizers.pyx -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\_funcs.pyx -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\ops.pxd -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\_funcs.pxd -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\__init__.pxd -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\gpu_ops.cpp -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\ops.cpp -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\optimizers.cpp -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\neural\_funcs.cpp -> build\lib.win-amd64-3.6\thinc\neural
#   copying thinc\extra\cache.pyx -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\eg.pyx -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\mb.pyx -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\search.pyx -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\cache.pxd -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\eg.pxd -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\mb.pxd -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\search.pxd -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\__init__.pxd -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\cache.cpp -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\eg.cpp -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\mb.cpp -> build\lib.win-amd64-3.6\thinc\extra
#   copying thinc\extra\search.cpp -> build\lib.win-amd64-3.6\thinc\extra
#   running build_ext
#   building 'thinc.linalg' extension
#   error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": http://landinghub.visualstudio.com/visual-cpp-build-tools
#
#   ----------------------------------------
#   Running setup.py clean for thinc
#   Running setup.py bdist_wheel for ujson: started
#   Running setup.py bdist_wheel for ujson: finished with status 'error'
#   Complete output from command C:\Users\Andrew\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\Andrew\\AppData\\Local\\Temp\\pip-build-bk63fsa9\\ujson\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\Andrew\AppData\Local\Temp\tmpdu0olh4ppip-wheel- --python-tag cp36:
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'ujson' extension
#   error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": http://landinghub.visualstudio.com/visual-cpp-build-tools
#
#   ----------------------------------------
#   Running setup.py clean for ujson
#   Running setup.py bdist_wheel for cytoolz: started
#   Running setup.py bdist_wheel for cytoolz: finished with status 'error'
#   Complete output from command C:\Users\Andrew\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\Andrew\\AppData\\Local\\Temp\\pip-build-bk63fsa9\\cytoolz\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\Andrew\AppData\Local\Temp\tmpuge1ck3xpip-wheel- --python-tag cp36:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.6
#   creating build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\compatibility.py -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\utils_test.py -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\_signatures.py -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\_version.py -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\__init__.py -> build\lib.win-amd64-3.6\cytoolz
#   creating build\lib.win-amd64-3.6\cytoolz\curried
#   copying cytoolz\curried\exceptions.py -> build\lib.win-amd64-3.6\cytoolz\curried
#   copying cytoolz\curried\operator.py -> build\lib.win-amd64-3.6\cytoolz\curried
#   copying cytoolz\curried\__init__.py -> build\lib.win-amd64-3.6\cytoolz\curried
#   copying cytoolz\dicttoolz.pyx -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\functoolz.pyx -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\itertoolz.pyx -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\recipes.pyx -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\utils.pyx -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\cpython.pxd -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\dicttoolz.pxd -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\functoolz.pxd -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\itertoolz.pxd -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\recipes.pxd -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\utils.pxd -> build\lib.win-amd64-3.6\cytoolz
#   copying cytoolz\__init__.pxd -> build\lib.win-amd64-3.6\cytoolz
#   creating build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\dev_skip_test.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_compatibility.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_curried.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_curried_toolzlike.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_dev_skip_test.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_dicttoolz.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_docstrings.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_doctests.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_embedded_sigs.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_functoolz.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_inspect_args.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_itertoolz.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_none_safe.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_recipes.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_serialization.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_signatures.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_tlz.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   copying cytoolz\tests\test_utils.py -> build\lib.win-amd64-3.6\cytoolz\tests
#   running build_ext
#   building 'cytoolz.dicttoolz' extension
#   error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": http://landinghub.visualstudio.com/visual-cpp-build-tools
#
#   ----------------------------------------
#   Running setup.py clean for cytoolz
# Failed to build spacy murmurhash cymem preshed thinc ujson cytoolz
# Installing collected packages: murmurhash, cymem, preshed, tqdm, cytoolz, plac, pyreadline, dill, termcolor, pathlib, msgpack-numpy, thinc, ujson, regex, spacy
#   Running setup.py install for murmurhash: started
#     Running setup.py install for murmurhash: finished with status 'error'
#     Complete output from command C:\Users\Andrew\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\Andrew\\AppData\\Local\\Temp\\pip-build-bk63fsa9\\murmurhash\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\Andrew\AppData\Local\Temp\pip-jc7vj98k-record\install-record.txt --single-version-externally-managed --compile:
#     running install
#     running build
#     running build_py
#     running build_ext
#     building 'murmurhash.mrmr' extension
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": http://landinghub.visualstudio.com/visual-cpp-build-tools
#
#     ----------------------------------------
#   Failed building wheel for spacy
#   Failed building wheel for murmurhash
#   Failed building wheel for cymem
#   Failed building wheel for preshed
#   Failed building wheel for thinc
#   Failed building wheel for ujson
#   Failed building wheel for cytoolz
# Command "C:\Users\Andrew\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\Andrew\\AppData\\Local\\Temp\\pip-build-bk63fsa9\\murmurhash\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\Andrew\AppData\Local\Temp\pip-jc7vj98k-record\install-record.txt --single-version-externally-managed --compile" failed with error code 1 in C:\Users\Andrew\AppData\Local\Temp\pip-build-bk63fsa9\murmurhash\
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# python: can't open file '<unprintable file name>': [Errno 2] No such file or directory

# %% [markdown]
# ## Lab Part 1
#
# ### Tokenization
#
# What:  Separate text into units such as sentences or words
#
# Why:   Gives structure to previously unstructured text
#
# Notes: Relatively easy with English language text, not easy with some languages
#
#
# "corpus" = collection of documents
#
# "corpora" = plural form of corpus

# %%
import spacy
import codecs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-62f2f26cb2b6> in <module>()
# ----> 1 import spacy
#       2 import codecs
#
# ModuleNotFoundError: No module named 'spacy'

# %%
nlp = spacy.load('en')

# %% [markdown]
# Jane Austen's Emma is in the `data/` directory as `emma.txt`
# If you are using a Azure Notebook, upload it somewhere
# convenient (e.g. `~/library`) and adjust the path in the next cell

# %%
# open it as a UTF-8 file.
emma_file = codecs.open('../../data/emma.txt', encoding='utf-8')

# %%
# Create an NLP analysis of the first 5000 characters of Emma:
emma = nlp(emma_file.read()[:5000])

# %%
# Do the same for Alice in Wonderland, which is in the data/ directory
# as alice-in-wonderland.txt

# %%
# Count the number of sentences in each novel.

# %%
# Count the number of words in each sentence

# %%
# Which novel has more average words per sentence?
# Given their target audience, is this what you would expect?

# %%
# For each novel, construct a set of all the distinct words used

# %%
# Calculate the lexical diversity of each novel (distinct words / word count)

# %%
# (Optional, only for the very keen)
# The nltk library includes a sample of project Gutenberg books in nltk.corpus.gutenberg
# Create a dataframe with the names of the novels, when they were written,
# whether they were for children, the lexical diversity and the average sentence length.
# Can you use logistic regression to predict the audience, based on the content?

# %% [markdown]
# ## Lab Part 2
#
# Words in context. The textacy library has some utility functions that make this easy.

# %%
# !pip install textacy
import textacy

# %%
# Does Jane Austen ever mention the word 'young' in Emma? What about Lewis Carroll?
# In what context does it appear?

# %%
# Where does the word 'cat' appear in Alice in Wonderland?

# %% [markdown]
# ## Lab Part 3 Part of speech tagging
#
# What:  Determine the part of speech of a word
#
# Why:   This can inform other methods and models such as Named Entity Recognition

# %%
# Jane Austen is very long-winded. The 25th sentence of Emma isn't
# too bad though: "She dearly loved her father, but he was no companion for her."
#
emma25 = list(emma.sents)[25]
print(emma25.text)

# %%
# Print out each word in this sentence and its part of speech

# %%
# (Optional extra)
# Who are the most commonly named characters in Emma? What about Alice in Wonderland?

# %%
# (Optional extra; harder)
# What are the most commonly referenced nouns that are not characters?

# %% [markdown]
# ## Lab Part 4 - Vectorisation
#
# What: Turn sentences and documents into arrays of numbers
#
# Why:  Then we can use machine learning techniques

# %%
# Use a count vectorizer (or tfidf vectorizer) to vectorise all the sentences
# in both Emma and Alice in Wonderland (in that order)

# %%
# How many sentences are there in Emma? Create a list of this length filled with the number zero.

# %%
# How many sentences are there in Alice in Wonderland? Create a list of this length filled with the number one.

# %%
# Create a list called 'which_document' by appending the second list to the first

# %%
# Create a KNearestCentroid classifier

# %%
# Train your KNearestCentroid classifier. Let X be the vectorisation of sentences, and let y
# be the 'which_document' list

# %%
# Make up a sentence about love, marriage and any other Jane Austen topics. 
# Transform it using your vectorizer, and then get your classifier to predict what sort of document
# it is

# %% [markdown]
# FWIW, a TFIDF vectoriser combined with KNearestCentroid classifier is known as a Rocchio search.

# %% [markdown]
# ## Lab Part 5

# %%
# Repeat lab 4 using spacy's implementation of word2vec as the vectoriser
